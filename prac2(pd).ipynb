# %%
#exercise number 2 (pandas)

# %%
import pandas as pd
data = pd.read_csv('melb_data.csv')

# %%
data
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
df['BuildingArea']
# Out:
# 0          NaN
# 1         79.0
# 2        150.0
# 3          NaN
# 4        142.0
#          ...
# 18391     89.0
# 18392    157.0
# 18393      NaN
# 18394    112.0
# 18395    139.0
# Name: BuildingArea, Length: 18396, dtype: float64

# %%
df['BuildingArea'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0          NaN
# 1         79.0
# 2        150.0
# 3          NaN
# 4        142.0
#          ...
# 18391     89.0
# 18392    157.0
# 18393      NaN
# 18394    112.0
# 18395    139.0
# Name: BuildingArea, Length: 18396, dtype: float64>

# %%
df['BuildingArea'].max()
# Out:
# 44515.0

# %%
df.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  Biggin  3/12/2016       2.5  ...       1.0  1.0     202.0           NaN
# 1  Biggin  4/02/2016       2.5  ...       1.0  0.0     156.0          79.0
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
df2 = pd.DataFrame(df , columns = ['Method','Suburb','SellerG'])
df2
# Out:
#       Method        Suburb     SellerG
# 0          S    Abbotsford      Biggin
# 1          S    Abbotsford      Biggin
# 2         SP    Abbotsford      Biggin
# 3         PI    Abbotsford      Biggin
# 4         VB    Abbotsford      Nelson
# ...      ...           ...         ...
# 18391     SP  Williamstown        Greg
# 18392     PI  Williamstown     Sweeney
# 18393      S     Yallambie  Buckingham
# 18394     SP    Yarraville     Village
# 18395     VB    Yarraville     Village
#
# [18396 rows x 3 columns]

# %%
df2.describe()
# Out:
#        Method     Suburb SellerG
# count   18396      18396   18396
# unique      5        330     305
# top         S  Reservoir  Nelson
# freq    12034        541    2002

# %%
df['Rooms']<4
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 18391     True
# 18392    False
# 18393    False
# 18394    False
# 18395    False
# Name: Rooms, Length: 18396, dtype: bool

# %%
df
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.iloc[2:5]
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2  Biggin  4/03/2017       2.5  ...       2.0  0.0     134.0         150.0
# 3  Biggin  4/03/2017       2.5  ...       2.0  1.0      94.0           NaN
# 4  Nelson  4/06/2016       2.5  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea  Lattitude Longtitude             Regionname  \
# 2     1900.0        Yarra   -37.8093   144.9944  Northern Metropolitan
# 3        NaN        Yarra   -37.7969   144.9969  Northern Metropolitan
# 4     2014.0        Yarra   -37.8072   144.9941  Northern Metropolitan
#
#    Propertycount
# 2         4019.0
# 3         4019.0
# 4         4019.0
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18396, step=1)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=18396, step=1)

# %%
df4 = df.copy
df4
# Out:
# <bound method NDFrame.copy of        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
# ...

# %%
df3 = df.fillna(value = '***')
df3
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date Distance  ... Bathroom  Car Landsize  \
# ...

# %%
df5 = df.dropna()
df5
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 1               2    Abbotsford  25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford     5 Charles St      3    h  1465000.0
# 4               6    Abbotsford      55a Park St      4    h  1600000.0
# 6              11    Abbotsford     124 Yarra St      3    h  1876000.0
# 7              14    Abbotsford    98 Charles St      2    h  1636000.0
# ...           ...           ...              ...    ...  ...        ...
# 15388       19732    Whittlesea    30 Sherwin St      3    h   601000.0
# 15389       19733  Williamstown      75 Cecil St      3    h  1050000.0
# 15390       19734  Williamstown    2/29 Dover Rd      1    u   385000.0
# 15392       19736       Windsor  201/152 Peel St      2    u   560000.0
# 15395       19739    Yarraville  54 Pentland Pde      6    h  2450000.0
#
#       Method        SellerG        Date  Distance  ...  Bathroom  Car  \
# ...

# %%
df.isna()
# Out:
#        Unnamed: 0  Suburb  Address  Rooms   Type  Price  Method  SellerG  \
# 0           False   False    False  False  False  False   False    False
# 1           False   False    False  False  False  False   False    False
# 2           False   False    False  False  False  False   False    False
# 3           False   False    False  False  False  False   False    False
# 4           False   False    False  False  False  False   False    False
# ...           ...     ...      ...    ...    ...    ...     ...      ...
# 18391       False   False    False  False  False  False   False    False
# 18392       False   False    False  False  False  False   False    False
# 18393       False   False    False  False  False  False   False    False
# 18394       False   False    False  False  False  False   False    False
# 18395       False   False    False  False  False  False   False    False
#
#         Date  Distance  ...  Bathroom    Car  Landsize  BuildingArea  \
# ...
